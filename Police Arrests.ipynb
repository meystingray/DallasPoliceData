# %%
library(data.table)

# %%
PA <- readRDS("C:/Users/sconroy/Desktop/Debug/PoliceArrests.RDS")

# %%
PA <- PA[ararrestdate != min(ararrestdate,na.rm = TRUE),]

# %%
plot(PA[,.N,by = "ararrestdate"])
# Out:
# plot without title

# %%
setDT(PA)

# %%
str(PA)
# Out:
# Classes 'data.table' and 'data.frame':	86306 obs. of  65 variables:
#  $ incidentnum    : chr  "022360-2020" "139125-2019" "197119-2019" "079584-2019" ...
#  $ arrestyr       : int  2020 2019 2019 2019 2019 2019 2019 2019 2019 2019 ...
#  $ arrestnumber   : chr  "20-004120" "19-024702" "19-035625" "19-013988" ...
#  $ ararrestdate   : POSIXct, format: "2020-02-02" "2019-07-10" ...
#  $ ararresttime   : chr  "22:51" "16:55" "22:45" "11:35" ...
#  $ arbkdate       : POSIXct, format: "2020-02-03 00:49:49" "2019-07-10 18:28:42" ...
#  $ arladdress     : chr  "600 DOGWOOD TRL" "N MASTERS DR & BRUTON RD" "400 S ERVAY ST" "7709 OLUSTA DR" ...
#  $ arlapt         : chr  "" "" "" "" ...
#  $ arlzip         : int  75224 75217 75201 75217 75202 75207 75220 75230 75211 75229 ...
#  $ arlcity        : chr  "DALLAS" "DALLAS" "DALLAS" "DALLAS" ...
#  $ arstate        : chr  "TX" "TX" "TX" "TX" ...
#  $ arlcounty      : chr  "DALLAS" "DALLAS" "DALLAS" "" ...
# ...

# %%
plot(PA$age)
# Out:
# plot without title

# %%
plot(PA[arlzip > 75000 & arlzip < 75500,.N,by = "arlzip"])
# Out:
# plot without title

# %%
table(PA$arweapon)
# Out:
#                                                  33                      Burn
#                        10                         3                         8
#                      Club                     Drugs                Explosives
#                        98                      1023                         4
# Firearm (Type Not Stated)       Gas/Carbon Monoxide                       Gun
#                        62                         1                      1850
#                   Handgun                Hands/Feet           Knife - Butcher
#                      1625                      2143                       107
#             Knife - Other            Knife - Pocket Lethal Cutting Instrument
#                       453                      1352                        62
#              Missle/Arrow                      None                     Other
#                         8                     44066                       730
# ...
